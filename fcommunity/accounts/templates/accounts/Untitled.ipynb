# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=20, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);
print X.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-00a6fc5a9d0c> in <module>()
#       7                        cluster_std=0.60, random_state=0)
#       8 plt.scatter(X[:, 0], X[:, 1], s=50);
# ----> 9 print X.type()
#      10
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
print kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
from collections import Counter, defaultdict
print(Counter(kmeans.labels_))
print Counter(kmeans.labels_)[0]

clusters_indices = defaultdict(list)
for index, c  in enumerate(kmeans.labels_):
    clusters_indices[c].append(index)
print"clusters_indices[1]: ", clusters_indices[1]
finalIndices = [0]*20
noMatchPoints = []
count = 1
for i in range (0, 3):
    if Counter(kmeans.labels_)[i] > 5:
        newList = []
        for j in clusters_indices[i]:
            currPoint = (X[j][0], X[j][1])
            newList.append(currPoint)
        arrayList = np.array(newList)
        print arrayList
    elif Counter(kmeans.labels_)[i] < 3:
        noMatchPoints.extend(clusters_indices[i])
    else:
        for j in clusters_indices[i]:
            finalIndices[j] = count
        count += 1
print noMatchPoints
print finalIndices
kmeans1 = KMeans(n_clusters=3)
kmeans1.fit(arrayList)
y_kmeans1 = kmeans.predict(arrayList)

plt.scatter(arrayList[:, 0], arrayList[:, 1], c=y_kmeans1, s=50, cmap='viridis')

centers = kmeans1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
# Out:
# Counter({2: 10, 0: 5, 1: 5})
# 5
# clusters_indices[1]:  [2, 5, 7, 10, 15]
# [[ 1.87271752  4.18069237]
#  [-0.60723648  3.79949752]
#  [ 1.43289271  4.37679234]
#  [-2.05957546  1.72940438]
#  [-1.43393556  3.14477977]
#  [-0.7887296   3.63931017]
#  [ 1.06269622  5.17635143]
#  [ 0.91433877  4.55014643]
#  [-1.7356513   3.01169164]
#  [ 1.24258802  4.50399192]]
# []
# [0, 0, 2, 0, 0, 2, 0, 2, 1, 1, 2, 0, 0, 0, 1, 2, 0, 1, 0, 1]

# %%
kmeans1 = KMeans(n_clusters=6)
kmeans1.fit(X)
y_kmeans1 = kmeans1.predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_kmeans1, s=50, cmap='viridis')

centers1 = kmeans1.cluster_centers_
plt.scatter(centers1[:, 0], centers1[:, 1], c='black', s=200, alpha=0.5);

# %%
np.random.rand(,2)
# Out:
#   File "<ipython-input-38-3e3bf8606a5c>", line 1
#     np.random.rand(,2)
#                    ^
# SyntaxError: invalid syntax

# %%
kmeans2 = KMeans(n_clusters=300/10)
kmeans2.fit(X)
y_kmeans2 = kmeans2.predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_kmeans2, s=50, cmap='viridis')

centers2 = kmeans2.cluster_centers_
plt.scatter(centers2[:, 0], centers2[:, 1], c='black', s=200, alpha=0.5);

# %%
cluster_map = pd.DataFrame()
cluster_map['data_index'] = x.index.values
cluster_map['cluster'] = kmeans.labels_
cluster_map[cluster_map.cluster == 3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4e88ba9b57d0> in <module>()
# ----> 1 cluster_map = pd.DataFrame()
#       2 cluster_map['data_index'] = x.index.values
#       3 cluster_map['cluster'] = kmeans.labels_
#       4 cluster_map[cluster_map.cluster == 3]
#
# NameError: name 'pd' is not defined

# %%
inst = 1
strin = ("team %s" % inst)
print strin
# Out:
# team 1

# %%
for i in range(1, 2):
    print i
# Out:
# 1

# %%
from geopy.distance.distance import vincenty

point1 = (51.5467509026, -1.3354038878)
point2 = (53.3980693202, -2.1838426659)
print vincenty(point1, point2).kilometers
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-53-ae31eb62d72f> in <module>()
# ----> 1 from geopy.distance.distance import vincenty
#       2
#       3 point1 = (51.5467509026, -1.3354038878)
#       4 point2 = (53.3980693202, -2.1838426659)
#       5 print vincenty(point1, point2).kilometers
#
# ImportError: No module named distance

# %%
teams = 8
leg = 1
numberOfLegs = 2 * (((teams / 2) + 1 * 2) - 1)
teamsList = []
for i in range(1, teams+1):
    teamsList.append(i)
if len(teamsList) % 2 == 1:
        teamsList[teams] = teams
teamCount = len(teamsList)
newTeamsList = []
print "Round %d:" % leg
for i in range(0, teamCount/2):
    print teamsList[i], " - ", teamsList[teamCount - 1 - i]
    newTeamsList.append(teamsList[i])
    newTeamsList.append(teamsList[teamCount - 1 - i])
print newTeamsList
leg += 1
generateNextDay(teamsList, newTeamsList, numberOfLegs, len(teamsList))
# Out:
# Round 1:
# 1  -  8
# 2  -  7
# 3  -  6
# 4  -  5
# [1, 8, 2, 7, 3, 6, 4, 5]
# Round 2:
# 8  -  5
# 4  -  6
# 3  -  7
# [8, 5, 4, 4, 3, 3]
# Round 3:
# 3  -  8
# 4  -  3
# 8  -  4
# [3, 5, 4, 3, 8, 4]
# Round 4:
# 8  -  4
# 8  -  3
# 4  -  3
# [8, 4, 8, 8, 4, 4]
# Round 5:
# 4  -  8
# 8  -  4
# 8  -  8
# [4, 4, 8, 4, 8, 8]
# Round 6:
# 8  -  8
# 8  -  4
# 8  -  4
# [8, 8, 8, 8, 8, 8]
# Round 7:
# 8  -  8
# 8  -  8
# 8  -  8
# [8, 8, 8, 8, 8, 8]
# Round 8:
# 8  -  8
# 8  -  8
# 8  -  8
# [8, 8, 8, 8, 8, 8]
# Round 9:
# 8  -  8
# 8  -  8
# 8  -  8
# [8, 8, 8, 8, 8, 8]

# %%
def generateNextDay(teamsList, newTeamsList, numberOfLegs, teamsCount):
    global leg
    if leg == numberOfLegs:
        return 1
    print "Round %d:" % leg
    if leg % 2 == 0:
        newerList = []
        print teamsList[teamCount - 1], " - ", newTeamsList[len(newTeamsList) - 1]
        newerList.append(teamsList[teamCount - 1])
        newerList.append(newTeamsList[len(newTeamsList) - 1])
        del newTeamsList[1]
        del newTeamsList[len(newTeamsList) - 1]
        for i in range(1, ((teamsCount + 1) / 2 - 1)):
            print newTeamsList[len(newTeamsList) - 1], " - ", newTeamsList[len(newTeamsList) - 2]
            newerList.append(newTeamsList[len(newTeamsList) - 1])
            newerList.append(newTeamsList[len(newTeamsList) - 1])
            del newTeamsList[len(newTeamsList) - 1]
            del newTeamsList[len(newTeamsList) - 1]
        print newerList
    else:
        newerList = []
        print newTeamsList[len(newTeamsList) - 1], " - ", teamsList[teamCount - 1]
        newerList.append(newTeamsList[len(newTeamsList) - 1])
        newerList.append(newTeamsList[1])
        del newTeamsList[len(newTeamsList) - 1]
        del newTeamsList[1]
        for i in range(1, ((teamsCount + 1) / 2 - 1)):
            print newTeamsList[len(newTeamsList) - 2], " - ", newTeamsList[len(newTeamsList) - 1]
            newerList.append(newTeamsList[len(newTeamsList) - 2])
            newerList.append(newTeamsList[len(newTeamsList) - 1])
            del newTeamsList[len(newTeamsList) - 1]
            del newTeamsList[len(newTeamsList) - 1]
        print newerList
    leg += 1
    generateNextDay(teamsList, newerList, numberOfLegs, len(teamsList))
